# %% [markdown]
# <a href="https://colab.research.google.com/github/Panuvat-Dan/Machine_learning_chula_class/blob/main/Error_Surface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
def sigmoid(X):
  return 1/(1+np.exp(-10*X))

X=np.arange(-10,10,0.1)
Y=sigmoid(X)
plt.plot(X,Y)

# %%
import numpy as np
import random

# y=2.5x+3.8
X=np.array([int(random.random()*10 for i in range(20)])
Y=2.5*X+3.8

W0=

# %%
import numpy as np

w1=np.arange(-10,10,0.1)
w2=np.arange(-10,10,0.1)
w1,w2=np.meshgrid(w1,w2)
w1.shape
# Out:
# (200, 200)

# %%
z=(1/(1+np.exp(-(-1.8+w1*0+w2*0))))**2 + (1/(1+np.exp(-(-1.8+w1*0+w2*1))))**2 +(1/(1+np.exp(-(-1.8+w1*1+w2*0))))**2+(1/(1+np.exp(-(-1.8+w1+w2)))-1)**2

# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D

plt.contour(w1,w2,z)
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_wireframe(w1,w2,z,rstride=5, cstride=5)
ax.view_init(-10, 60)
plt.draw()
